# %% [markdown]
# # Superstore Sales Dataset
# **Data Analysis Project**
#
# # Submitted By
# **Poonam Rajora**
#
# # Project Description
# **This project focuses on Data Cleaning,exploratory data analysis(EDA) and forecasting model of the Superstore Sales dataset using python.**
#
# # Technologies Used
# **python, pandas, numpy, jupyter notebook,matplotlib.pyplot,seaborn,mae and rmse**

# %% [markdown]
# # Business Problem
# A retail company wants to predict future sales so that it can:
# Manage inventory efficiently.
# Reduce stock shortages and overstock.
# Increase profit.
# Improve demand planning.

# %% [markdown]
# # Business Objectives
# The objective of this project is to analyze historical sales data, identify trends and seasonal patterns, forecast future sales, and provide actionable business recommendations to improve inventory management, marketing strategies, and overall business performance.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import mean_squared_error , mean_absolute_error

# %%
df = pd.read_csv("C:\Sample - Superstore.csv",encoding="latin1")
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode  ...                                       Product Name     Sales Quantity Discount    Profit
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class  ...                  Bush Somerset Collection Bookcase  261.9600        2     0.00   41.9136
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class  ...  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3     0.00  219.5820
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class  ...  Self-Adhesive Address Labels for Typewriters b...   14.6200        2     0.00    6.8714
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class  ...      Bretford CR4500 Series Slim Rectangular Table  957.5775        5     0.45 -383.0310
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class  ...                     Eldon Fold 'N Roll Cart System   22.3680        2     0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  ...                                       Product Name    Sales Quantity Discount   Profit
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class  ...                             Ultra Door Pull Handle   25.248        3      0.2   4.1028
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class  ...  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960        2      0.0  15.6332
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class  ...                              Aastra 57i VoIP phone  258.576        2      0.2  19.3932
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class  ...  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600        4      0.0  13.3200
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class  ...  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160        2      0.0  72.9480
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount       Profit
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203    28.656896
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452   234.260108
# min       1.000000   1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000    29.364000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.describe(include='object')
# Out:
#               Order ID Order Date   Ship Date       Ship Mode Customer ID  Customer Name  ...       State Region       Product ID         Category Sub-Category     Product Name
# count             9994       9994        9994            9994        9994           9994  ...        9994   9994             9994             9994         9994             9994
# unique            5009       1237        1334               4         793            793  ...          49      4             1862                3           17             1850
# top     CA-2017-100111   9/5/2016  12/16/2015  Standard Class    WB-21850  William Brown  ...  California   West  OFF-PA-10001970  Office Supplies      Binders  Staple envelope
# freq                14         38          35            5968          37             37  ...        2001   3203               19             6026         1523               48
#
# [4 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %% [markdown]
# # outliers detection

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df[['Sales','Profit','Quantity','Discount']])
plt.show()

# %%
num_cols = ['Sales','Profit','Quantity','Discount']

for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    df = df[(df[col] >= lower) & (df[col] <= upper)]

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df[['Sales','Profit','Quantity','Discount']])
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
df['year'] = df['Order Date'].dt.month

# %%
df['month'] = df['Order Date'].dt.month

# %%
df['month_name'] = df['Order Date'].dt.month_name()

# %% [markdown]
# # EDA

# %%
df['Sales'].sum()
# Out:
# np.float64(2297200.8603)

# %%
df['Profit'].sum()
# Out:
# np.float64(286397.0217)

# %%
df['Sales'].mean()
# Out:
# np.float64(229.85800083049827)

# %%
df['Quantity'].mean()
# Out:
# np.float64(3.789573744246548)

# %% [markdown]
# # Time-Based Data Analysis

# %%
monthly_sales = df.groupby(pd.Grouper(key='Order Date',freq='M'))['Sales'].sum()
monthly_sales
# Out:
# C:\Users\BBC IT HUb\AppData\Local\Temp\ipykernel_24560\3724076835.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_sales = df.groupby(pd.Grouper(key='Order Date',freq='M'))['Sales'].sum()
# Order Date
# 2014-01-31     14236.8950
# 2014-02-28      4519.8920
# 2014-03-31     55691.0090
# 2014-04-30     28295.3450
# 2014-05-31     23648.2870
# 2014-06-30     34595.1276
# 2014-07-31     33946.3930
# 2014-08-31     27909.4685
# 2014-09-30     81777.3508
# 2014-10-31     31453.3930
# 2014-11-30     78628.7167
# 2014-12-31     69545.6205
# 2015-01-31     18174.0756
# 2015-02-28     11951.4110
# 2015-03-31     38726.2520
# 2015-04-30     34195.2085
# 2015-05-31     30131.6865
# 2015-06-30     24797.2920
# 2015-07-31     28765.3250
# 2015-08-31     36898.3322
# 2015-09-30     64595.9180
# 2015-10-31     31404.9235
# 2015-11-30     75972.5635
# 2015-12-31     74919.5212
# 2016-01-31     18542.4910
# 2016-02-29     22978.8150
# 2016-03-31     51715.8750
# 2016-04-30     38750.0390
# 2016-05-31     56987.7280
# 2016-06-30     40344.5340
# 2016-07-31     39261.9630
# 2016-08-31     31115.3743
# 2016-09-30     73410.0249
# 2016-10-31     59687.7450
# 2016-11-30     79411.9658
# 2016-12-31     96999.0430
# 2017-01-31     43971.3740
# 2017-02-28     20301.1334
# 2017-03-31     58872.3528
# 2017-04-30     36521.5361
# 2017-05-31     44261.1102
# 2017-06-30     52981.7257
# 2017-07-31     45264.4160
# 2017-08-31     63120.8880
# 2017-09-30     87866.6520
# 2017-10-31     77776.9232
# 2017-11-30    118447.8250
# 2017-12-31     83829.3188
# Freq: ME, Name: Sales, dtype: float64

# %%
monthly_sales.plot(figsize=(12,5))
plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# # Trend Analysis

# %%
plt.figure(figsize=(12,5))
plt.plot(monthly_sales)
plt.title('Sales Trend')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# # Seasonality Analysis

# %%
season = df.groupby('month_name')['Sales'].mean()
season
# Out:
# month_name
# April        206.230731
# August       225.274877
# December     231.032318
# February     199.170838
# January      249.146550
# July         207.377601
# June         212.996763
# March        294.548116
# May          210.923553
# November     239.606438
# October      244.594609
# September    222.451154
# Name: Sales, dtype: float64

# %%
season.plot(kind='bar',figsize=(10,5))
plt.title('Average Monthly Sales')
plt.show()

# %% [markdown]
# # Region-wise Sales

# %%
region_sales = df.groupby('Region')['Sales'].sum()
region_sales
# Out:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %%
region_sales.plot(kind='bar')
plt.title('Region Sales')
plt.show()

# %% [markdown]
# # Category-wise Sales

# %%
category_sales = df.groupby('Category')['Sales'].sum()
category_sales
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
category_sales.plot(kind='bar')
plt.title('Category Sales')
plt.show()

# %% [markdown]
# # Profit Analysis

# %%
profit = df.groupby('Category')['Profit'].sum()
profit
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
profit.plot(kind='bar')
plt.title('Category Profit')
plt.show()

# %% [markdown]
# # Discount Analysis

# %%
plt.scatter(df['Discount'],df['Profit'])
plt.title('Discount vs Profit')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# # Forecasting

# %%
monthly_sales = df.groupby(pd.Grouper(key='Order Date',freq='M'))['Sales'].sum()
# Out:
# C:\Users\BBC IT HUb\AppData\Local\Temp\ipykernel_24560\839246692.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_sales = df.groupby(pd.Grouper(key='Order Date',freq='M'))['Sales'].sum()

# %%
train = monthly_sales[:-6]
test = monthly_sales[-6:]

# %%
forecast = [train.mean()]*len(test)

# %% [markdown]
# # Model Evaluation

# %%
# MAE
mae = mean_absolute_error(test,forecast)
print(mae)
# Out:
# 36029.698183333334

# %%
#RMSE
rmse = np.sqrt(mean_squared_error(test,forecast))
print(rmse)
# Out:
# 42500.492338965

# %% [markdown]
# # Business Insights
# 1. Monthly sales trend shows business growth/decline.
# 2.Sales vary across months due to seasonal demand.
# 3.Some regions contribute more revenue than others.
# 4.Technology/Furniture/Office Supplies perform differently.
# 5.High discounts often reduce profit.
# 6.Future sales forecasting supports better inventory planning.

# %% [markdown]
# # Summary

# %%
print("=" * 50)
print("Project Superstore Sales")
print("=" * 50)

print("rows and columns:",df.shape)
print("missing values:",df.isnull().sum())
print("duplicates rows:",df.duplicated().sum())
print("total sales:",df['Sales'].sum())
print("total profit:",df['Profit'].sum())
print("average profit:",df['Profit'].mean())
print("maximum sales:",df['Sales'].max())
print("minimum sales:",df['Sales'].min())
print("top 10 states by sales:",df.groupby('Category')['Profit'].sum().sort_values(ascending=False))
print("top 10 cities by sales:",df.groupby('City')['Sales'].sum().sort_values(ascending=False).head())
print("time based analysis:",df.groupby(pd.Grouper(key='Order Date',freq='M'))['Sales'].sum())
print("season based analysis:",df.groupby('month_name')['Sales'].mean())
print("region-wise sales:",df.groupby('Region')['Sales'].sum())
print("profit analysis:",df.groupby('Category')['Profit'].sum())
print("category-wise sales:",df.groupby('Category')['Sales'].sum())
print("ship mode count:",df['Ship Mode'].value_counts())
print("top 10 products by sales:",df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head())
print("highest discount:",df['Discount'].max())
print("sales forecasting:" ,df.groupby(pd.Grouper(key='Order Date',freq='M'))['Sales'].sum())
print("model evaluation(MAE):",mean_absolute_error(test,forecast))
print("model evaluation(RMSE):",np.sqrt(mean_squared_error(test,forecast)))

print("=" * 50)
print("dataset saved successfully",df.to_csv('Superstore Sales',index=False))
print("=" * 50)
# Out:
# ==================================================
# Project Superstore Sales
# ==================================================
# rows and columns: (9994, 24)
# missing values: Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# year             0
# month            0
# month_name       0
# dtype: int64
# duplicates rows: 0
# total sales: 2297200.8603
# total profit: 286397.0217
# average profit: 28.65689630778467
# maximum sales: 22638.48
# minimum sales: 0.444
# top 10 states by sales: Category
# Technology         145454.9481
# Office Supplies    122490.8008
# Furniture           18451.2728
# Name: Profit, dtype: float64
# top 10 cities by sales: City
# New York City    256368.161
# Los Angeles      175851.341
# Seattle          119540.742
# San Francisco    112669.092
# Philadelphia     109077.013
# Name: Sales, dtype: float64
# time based analysis: Order Date
# 2014-01-31     14236.8950
# 2014-02-28      4519.8920
# 2014-03-31     55691.0090
# 2014-04-30     28295.3450
# 2014-05-31     23648.2870
# 2014-06-30     34595.1276
# 2014-07-31     33946.3930
# 2014-08-31     27909.4685
# 2014-09-30     81777.3508
# 2014-10-31     31453.3930
# 2014-11-30     78628.7167
# 2014-12-31     69545.6205
# 2015-01-31     18174.0756
# 2015-02-28     11951.4110
# 2015-03-31     38726.2520
# 2015-04-30     34195.2085
# 2015-05-31     30131.6865
# 2015-06-30     24797.2920
# 2015-07-31     28765.3250
# 2015-08-31     36898.3322
# 2015-09-30     64595.9180
# 2015-10-31     31404.9235
# 2015-11-30     75972.5635
# 2015-12-31     74919.5212
# 2016-01-31     18542.4910
# 2016-02-29     22978.8150
# 2016-03-31     51715.8750
# 2016-04-30     38750.0390
# 2016-05-31     56987.7280
# 2016-06-30     40344.5340
# 2016-07-31     39261.9630
# 2016-08-31     31115.3743
# 2016-09-30     73410.0249
# 2016-10-31     59687.7450
# 2016-11-30     79411.9658
# 2016-12-31     96999.0430
# 2017-01-31     43971.3740
# 2017-02-28     20301.1334
# 2017-03-31     58872.3528
# 2017-04-30     36521.5361
# 2017-05-31     44261.1102
# 2017-06-30     52981.7257
# 2017-07-31     45264.4160
# 2017-08-31     63120.8880
# 2017-09-30     87866.6520
# 2017-10-31     77776.9232
# 2017-11-30    118447.8250
# 2017-12-31     83829.3188
# Freq: ME, Name: Sales, dtype: float64
# season based analysis: month_name
# April        206.230731
# August       225.274877
# December     231.032318
# February     199.170838
# January      249.146550
# July         207.377601
# June         212.996763
# March        294.548116
# May          210.923553
# November     239.606438
# October      244.594609
# September    222.451154
# Name: Sales, dtype: float64
# region-wise sales: Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64
# profit analysis: Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64
# category-wise sales: Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64
# ship mode count: Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64
# top 10 products by sales: Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# Name: Sales, dtype: float64
# highest discount: 0.8
# sales forecasting: Order Date
# 2014-01-31     14236.8950
# 2014-02-28      4519.8920
# 2014-03-31     55691.0090
# 2014-04-30     28295.3450
# 2014-05-31     23648.2870
# 2014-06-30     34595.1276
# 2014-07-31     33946.3930
# 2014-08-31     27909.4685
# 2014-09-30     81777.3508
# 2014-10-31     31453.3930
# 2014-11-30     78628.7167
# 2014-12-31     69545.6205
# 2015-01-31     18174.0756
# 2015-02-28     11951.4110
# 2015-03-31     38726.2520
# 2015-04-30     34195.2085
# 2015-05-31     30131.6865
# 2015-06-30     24797.2920
# 2015-07-31     28765.3250
# 2015-08-31     36898.3322
# 2015-09-30     64595.9180
# 2015-10-31     31404.9235
# 2015-11-30     75972.5635
# 2015-12-31     74919.5212
# 2016-01-31     18542.4910
# 2016-02-29     22978.8150
# 2016-03-31     51715.8750
# 2016-04-30     38750.0390
# 2016-05-31     56987.7280
# 2016-06-30     40344.5340
# 2016-07-31     39261.9630
# 2016-08-31     31115.3743
# 2016-09-30     73410.0249
# 2016-10-31     59687.7450
# 2016-11-30     79411.9658
# 2016-12-31     96999.0430
# 2017-01-31     43971.3740
# 2017-02-28     20301.1334
# 2017-03-31     58872.3528
# 2017-04-30     36521.5361
# 2017-05-31     44261.1102
# 2017-06-30     52981.7257
# 2017-07-31     45264.4160
# 2017-08-31     63120.8880
# 2017-09-30     87866.6520
# 2017-10-31     77776.9232
# 2017-11-30    118447.8250
# 2017-12-31     83829.3188
# Freq: ME, Name: Sales, dtype: float64
# model evaluation(MAE): 36029.698183333334
# model evaluation(RMSE): 42500.492338965
# ==================================================
# C:\Users\BBC IT HUb\AppData\Local\Temp\ipykernel_24560\2507279526.py:15: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   print("time based analysis:",df.groupby(pd.Grouper(key='Order Date',freq='M'))['Sales'].sum())
# C:\Users\BBC IT HUb\AppData\Local\Temp\ipykernel_24560\2507279526.py:23: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   print("sales forecasting:" ,df.groupby(pd.Grouper(key='Order Date',freq='M'))['Sales'].sum())
# dataset saved successfully None
# ==================================================

# %% [markdown]
# # Business Recommendation
# Increase stock before high-demand months.
# Reduce unnecessary discounts.
# Focus marketing on high-profit categories.
# Improve performance in low-sales regions.
# Monitor monthly sales trends regularly.
# Use forecasting for inventory and supply-chain planning.
